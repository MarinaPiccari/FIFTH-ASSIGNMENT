# %% [markdown]
# ## Glob
# ##### Marina Piccari
# #### 1904900

# %%
from Bio import SeqIO
import numpy as np


blosum62 = [['A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'K', 'L', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V', 'W', 'Y'],
            ['A', 4, 0, -2, -1, -2, 0, -2, -1, -1, -1, -1, -2, -1, -1, -1, 1, 0, 0, -3, -2],
            ['C', 0, 9, -3, -4, -2, -3, -3, -1, -3, -1, -1, -3, -3, -3, -3, -1, -1, -1, -2, -2],
            ['D', -2, -3, 6, 2, -3, -1, -1, -3, -1, -4, -3, 1, -1, 0, -2, 0, -1, -3, -4, -3],
            ['E', -1, -4, 2, 5, -3, -2,  0, -3, 1, -3, -2, 0, -1, 2, 0, 0, -1, -2, -3, -2],
            ['F', -2, -2, -3, -3, 6, -3, -1, 0, -3, 0, 0, -3, -4, -3, -3, -2, -2, -1, 1, 3],
            ['G', 0, -3, -1, -2, -3, 6, -2, -4, -2, -4, -3, 0, -2, -2, -2, 0, -2, -3, -2, -3],
            ['H', -2, -3, -1, 0, -1, -2, 8, -3, -1, -3, -2, 1, -2, 0, 0, -1, -2, -3, -2, 2],
            ['I', -1, -1, -3, -3, 0, -4, -3, 4, -3, 2, 1, -3, -3, -3, -3, -2, -1 ,3, -3, -1],
            ['K', -1, -3, -1, 1, -3, -2, -1, -3, 5, -2, -1, 0, -1, 1, 2, 0, -1, -2, -3, -2],
            ['L', -1, -1, -4, -3, 0, -4, -3, 2, -2, 4, 2, -3, -3, -2, -2, -2, -1, 1, -2, -1],
            ['M', -1, -1, -3, -2, 0, -3, -2, 1, -1, 2, 5, -2, -2, 0, -1, -1, -1, 1, -1, -1],
            ['N', -2, -3, 1, 0, -3, 0, 1, -3, 0, -3, -2, 6, -2, 0, 0, 1, 0, -3, -4, -2],
            ['P', -1, -3, -1, -1, -4, -2, -2, -3, -1, -3, -2, -2, 7, -1, -2, -1, -1, -2, -4, -3],
            ['Q', -1, -3, 0, 2, -3, -2, 0, -3, 1, -2, 0, 0, -1, 5, 1, 0, -1, -2, -2, -1],
            ['R', -1, -3, -2, 0, -3, -2, 0, -3, 2, -2, -1, 0, -2, 1, 5, -1, -1, -3, -3, -2],
            ['S', 1, -1, 0, 0, -2, 0, -1, -2, 0, -2, -1, 1, -1, 0, -1, 4, 1, -2, -3, -2],
            ['T', 0, -1, -1, -1, -2, -2, -2, -1, -1, -1, -1, 0, -1, -1, -1, 1, 5, 0, -2, -2],
            ['V', 0, -1, -3, -2, -1, -3, -3,  3, -2, 1, 1, -3, -2, -2, -3, -2, 0, 4, -3, -1],
            ['W', -3, -2, -4, -3, 1, -2, -2, -3, -3, -2, -1, -4, -4, -2, -3, -3, -2, -3, 11, 2],
            ['Y', -2, -2, -3, -2, 3, -3, 2, -1, -2, -1, -1, -2, -3, -1, -2, -2, -2, -1, 2, 7]]



L = []
for record in SeqIO.parse("rosalind_glob.fasta", "fasta"):
    L.append(record.seq)
v, w = L[0], L[1]
m, n = len(v) + 1, len(w) + 1
V, W = [], []

d = blosum62[0]
    
M = np.zeros ((m, n))
for x in range(m):
    M[x, 0] = x
for y in range(n):
    M[0, y] = y
    
for i in range(m):
        for j in range(n):
            if i == 0 and j == 0:
                M[i][j] = 0
            elif i == 0 and j > 0:
                M[i][j] = -5*j
            elif i > 0 and j == 0:
                M[i][j] = -5*i
            elif v[i-1] == w[j-1]:
                M[i][j] = M[i-1][j-1] + blosum62[d.index(v[i-1])+1][d.index(v[i-1])+1]
            else:
                M[i][j] = max(M[i][j-1]-5, M[i-1][j]-5, M[i-1][j-1] + blosum62[d.index(v[i-1])+1][d.index(w[j-1])+1])

print ("%.0f" % (M[-1][-1]))
# Out:
# 1903
