# %% [markdown]
# ## Prot
# ##### Marina Piccari
# #### 1904900

# %%
pip install biop
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from Bio.Seq import Seq

with open ('rosalind_prot.fasta', 'r') as f:
    RNA = Seq(str(f.readline()))
    prot = RNA.translate(to_stop=True)
    print (prot)
# Out:
# ...
# C:\Users\122002\anaconda3\lib\site-packages\Bio\Seq.py:2334: BiopythonWarning: Partial codon, len(sequence) not a multiple of three. Explicitly trim the sequence or add trailing N before translation. This may become an error in future.
#   warnings.warn(
